# %% [markdown]
# Import the Libraries

# %%
import pandas as pd

# %% [markdown]
# Load the dataset from the local file

# %%
df=pd.read_csv("F:/Data set/weather.csv")

# %% [raw]
# EXPLORE THE DATA

# %%
df.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
#check for the top five items on the data frame
df.head(5)
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  1/1/2024      8.0     24.3       0.0          3.4       6.3          NW
# 1  1/2/2024     14.0     26.9       3.6          4.4       9.7         ENE
# 2  1/3/2024     13.7     23.4       3.6          5.8       3.3          NW
# 3  1/4/2024     13.3     15.5      39.8          7.2       9.1          NW
# 4  1/5/2024      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity3pm  Pressure9am  \
# 0           30.0         SW         NW  ...           29       1019.7
# 1           39.0          E          W  ...           36       1012.4
# 2           85.0          N        NNE  ...           69       1009.5
# 3           54.0        WNW          W  ...           56       1005.5
# 4           50.0        SSE        ESE  ...           49       1018.3
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
#Its shows the total number of unique values in each column.
#It can be applied on a single column as on whole dataframe.
df.nunique()
# Out:
# Date             366
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %%
#check for unique values in each column
df["Rainfall"].nunique()
# Out:
# 47

# %%
# show the total no. of non-null values in each column.It can be applied on a single column as well as whole dataframe.
df.count()
# Out:
# Date             366
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
#n a column ,it shows all the unique values with their count. It can be applied on single column only.
df['RainTomorrow'].value_counts()
# Out:
# RainTomorrow
# No     300
# Yes     66
# Name: count, dtype: int64

# %%
#provides basic information about the datframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           366 non-null    object
#  1   MinTemp        366 non-null    float64
#  2   MaxTemp        366 non-null    float64
#  3   Rainfall       366 non-null    float64
#  4   Evaporation    366 non-null    float64
#  5   Sunshine       363 non-null    float64
#  6   WindGustDir    363 non-null    object
#  7   WindGustSpeed  364 non-null    float64
#  8   WindDir9am     335 non-null    object
#  9   WindDir3pm     365 non-null    object
#  10  WindSpeed9am   359 non-null    float64
#  11  WindSpeed3pm   366 non-null    int64
#  12  Humidity9am    366 non-null    int64
#  13  Humidity3pm    366 non-null    int64
#  14  Pressure9am    366 non-null    float64
#  15  Pressure3pm    366 non-null    float64
#  16  Cloud9am       366 non-null    int64
# ...

# %%
# Check for missing values
missing_data = df.isnull().sum()
print(missing_data[missing_data > 0])
# Out:
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# dtype: int64

# %% [markdown]
# What are the basic statistical summaries of the dataset?

# %%
# Summary statistics for numeric columns
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %% [markdown]
# How are temperature values distributed?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for Rainfall	
plt.figure(figsize=(8, 5))
sns.histplot(df['MaxTemp'], kde=True)
plt.title("MaxTemp Distribution")
plt.xlabel("MaxTemp(°C)")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for Rainfall	
plt.figure(figsize=(8, 5))
sns.histplot(df['MinTemp'], kde=True)
plt.title("MinTemp Distribution")
plt.xlabel("MinTemp(°C)")
plt.show()

# %% [markdown]
# Is there a seasonal pattern in temperature, rainfall, or other variables?

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['month'] = df['Date'].dt.month

# Average temperature by month
monthly_avg = df.groupby('month')['MaxTemp'].mean()

plt.figure(figsize=(10, 6))
monthly_avg.plot(kind='bar')
plt.title("Average Monthly Temperature")
plt.xlabel("Month")
plt.ylabel("Maximum Temperature (°C)")
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['month'] = df['Date'].dt.month

# Average temperature by month
monthly_avg = df.groupby('month')['MinTemp'].mean()

plt.figure(figsize=(10, 6))
monthly_avg.plot(kind='bar')
plt.title("Average Monthly MinTemp")
plt.xlabel("Month")
plt.ylabel("Minimum Temperature (°C)")
plt.show()

# %% [markdown]
# What is the trend of maximum and minimum temperatures over time?

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['MaxTemp'], label="Max Temp")
plt.plot(df['Date'], df['MinTemp'], label="Min Temp")
plt.title("Max and Min Temperature Over Time")
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.show()

# %% [markdown]
# Is there a relationship between temperature and humidity?

# %%
# Scatter plot for temperature vs humidity
plt.figure(figsize=(8, 6))
sns.scatterplot(x='temperature', y='humidity', data=df)
plt.title("Temperature vs Humidity")
plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity (%)")
plt.show()
